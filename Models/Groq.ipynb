# %%
# !pip install langchain_groq

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langchain_core.output_parsers import StrOutputParser
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model='llama-3.1-8b-instant')

# %%
prompt = PromptTemplate(template='Translate the following text "{text}" to {mentioned} language',input_variables=['text','mentioned'])

# %%
parser = StrOutputParser()

# %%
chain = prompt | llm | parser

# %%
chain.invoke({'text':'I love you','mentioned':"Hindi"})
# Out:
# 'The translation of "I love you" in Hindi is:\n\n"मैं तुमसे प्यार करता/करती हूँ" \n\nThis can be simplified to:\n\n"मैं तुमसे प्यार करता हूँ" (male speaker) \n"मैं तुमसे प्यार करती हूँ" (female speaker)\n\nHowever, in Hindi, it\'s common to use a more casual and affectionate way of saying "I love you", which is:\n\n"तुमसे प्यार है"\n\nThis can also be used in a more informal setting.'

# %%
chain.invoke({'text':'I love you','mentioned':"French"})
# Out:
# 'The translation of "I love you" to French is:\n\n"Je t\'aime."\n\nHowever, if you want to be more formal, you can say:\n\n"J\'ai de l\'amour pour toi" or "Je vous aime" (for multiple people).\n\nBut "Je t\'aime" is the most common and informal way to express love in French, similar to the English phrase "I love you."'
