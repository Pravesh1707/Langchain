# %%
from langchain_community.utilities import OpenWeatherMapAPIWrapper
from langchain_community.tools.openweathermap.tool import OpenWeatherMapQueryRun
from langchain_community.document_loaders.weather import WeatherDataLoader
# Out:
# /var/folders/cf/t0bj31ws20944pwkbddw0ylh0000gn/T/ipykernel_87295/186153403.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import OpenWeatherMapAPIWrapper

# %%
# !pip install pyowm

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
city = input("enter the city")

# %%
weather_wrapper = OpenWeatherMapAPIWrapper()
data = WeatherDataLoader(client=weather_wrapper,places=["New delhi"])

# %%
result = data.load()

# %%
for doc in result:
    print(doc.page_content)
# Out:
# In New delhi, the current weather is as follows:
# Detailed status: overcast clouds
# Wind speed: 2.57 m/s, direction: 140°
# Humidity: 62%
# Temperature:
#   - Current: 34.01°C
#   - High: 34.01°C
#   - Low: 33.09°C
#   - Feels like: 41.01°C
# Rain: {}
# Heat index: None
# Cloud cover: 100%
