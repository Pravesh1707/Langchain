# %% [markdown]
# # Indexes
# ### Document Loader --> Text_Splitter --> Embedding --> Vectors

# %% [markdown]
# ## Doc Loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader('requirements.txt',encoding='utf-8')

# %%
docs = loader.load()

# %%
len(docs)
# Out:
# 1

# %%
print(docs[0].page_content)
# Out:
# Langchain
# python-dotenv
# langchain_community
# langchain_openai
# langchain_huggingface
# sentence-transformers
# cromadb
# faiss-gpu

# %%
print(docs[0].metadata)
# Out:
# {'source': 'requirements.txt'}

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
loader = PyMuPDFLoader("./Data/Sample-filled-in-MR.pdf")

# %%
doc = loader.load()

# %%
print(doc[0].page_content)
# Out:
# - 1 -
#
# SAMPLE
# (All names and details provided in this sample are fictitious.
# Some fields have been deliberately left blank.)
#
#
# MEDICAL REPORT
#
# SECTION 1: PATIENT’S PARTICULARS
#
# Full name of patient: Mr Tan Ah Kow
#
# NRIC/FIN/Passport no. of patient: S1111111X
#
# Age of patient: 55 years old
#
# SECTION 2: DOCTOR’S PARTICULARS
#
# Full name of doctor: Tan Ah Moi
#
# NRIC/FIN/Passport no. of doctor: S2222222Z
#
#
# MCR no. of doctor: 333333
#
# Hospital / Clinic name and address: 1 Blackacre Hospital, Singapore 01010101
#
#
#
# Doctor’s qualifications and experience in this area of work:
#
#
# [To set out details]

# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader('./Data/Walmart_Sales.csv',encoding ='utf-8')

# %%
doc = loader.load()

# %%
len(doc)
# Out:
# 6435

# %%
print(doc[2].page_content)
# Out:
# Store: 1
# Date: 19-02-2010
# Weekly_Sales: 1611968.17
# Holiday_Flag: 0
# Temperature: 39.93
# Fuel_Price: 2.514
# CPI: 211.2891429
# Unemployment: 8.106

# %% [markdown]
# # Text Splitter

# %%
doc
# Out:
# [Document(metadata={'producer': '', 'creator': '', 'creationdate': '2015-09-19T08:45:51+08:00', 'source': './Data/Sample-filled-in-MR.pdf', 'file_path': './Data/Sample-filled-in-MR.pdf', 'total_pages': 10, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2015-09-19T08:45:51+08:00', 'trapped': '', 'modDate': "D:20150919084551+08'00'", 'creationDate': "D:20150919084551+08'00'", 'page': 0}, page_content='- 1 - \n \nSAMPLE \n(All names and details provided in this sample are fictitious.  \nSome fields have been deliberately left blank.) \n \n \nMEDICAL REPORT \n \nSECTION 1: PATIENT’S PARTICULARS \n \nFull name of patient: Mr Tan Ah Kow \n \nNRIC/FIN/Passport no. of patient: S1111111X \n \nAge of patient: 55 years old \n \nSECTION 2: DOCTOR’S PARTICULARS \n \nFull name of doctor: Tan Ah Moi \n \nNRIC/FIN/Passport no. of doctor: S2222222Z  \n \n \nMCR no. of doctor: 333333 \n \nHospital / Clinic name and address: 1 Blackacre Hospital, Singapore 01
# ...

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
CharacterTextSplitter(chunk=200, chunk_overlap=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 CharacterTextSplitter(chunk=200, chunk_overlap=0)
#
# NameError: name 'CharacterTextSplitter' is not defined

# %% [markdown]
# # Embedding

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
embedding = OpenAIEmbeddings(model='text-embedding-3-large')

# %%
text ="Hi i am Pravesh Kumar, I am a Data Engineer and I am working on Langchain and LLMs"

# %%
type(doc)
# Out:
# list

# %%
new_docs = textfor metadata, page_content from doc:
# Out:
#   Input In [43]
#     new_docs = text for metadata, page_content from doc:
#                     ^
# SyntaxError: invalid syntax

# %%
#result = embedding.embed_query(text)
doc_result = embedding.embed_documents(doc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       1 #result = embedding.embed_query(text)
# ----> 2 doc_result = embedding.embed_documents(doc)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# ...

# %%
print(result)
# Out:
# [-0.038665771484375, 0.0295867919921875, -0.022796630859375, -0.0227203369140625, 0.026397705078125, -0.00955963134765625, -0.005401611328125, 0.006824493408203125, -0.0283050537109375, 0.00710296630859375, 0.0172576904296875, -0.034088134765625, -0.017822265625, -0.017364501953125, 0.0180511474609375, 0.0157012939453125, -0.00818634033203125, -0.01102447509765625, -0.010955810546875, -0.007328033447265625, 0.0142364501953125, -0.038238525390625, -0.0260009765625, -0.01084136962890625, 0.0012369155883789062, 0.0164642333984375, 0.025970458984375, -0.0115814208984375, -0.041229248046875, -0.01340484619140625, 0.01438140869140625, 0.00914764404296875, 0.006885528564453125, -0.00991058349609375, -0.0026874542236328125, -0.037750244140625, 0.03155517578125, -0.002086639404296875, -0.0162200927734375, 0.01788330078125, -0.00339508056640625, 0.0231781005859375, -0.051361083984375, 0.00592803955078125, 0.0168914794921875, -0.00974273681640625, 0.0235595703125, 0.0018453598022460938, 0.03601
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embedding = HuggingFaceEmbeddings(model='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
result = embedding.embed_query(text)

# %%
result
# Out:
# [-0.0019602933898568153,
#  -0.04790196940302849,
#  0.021603398025035858,
#  -0.056939952075481415,
#  -0.012547443620860577,
#  -0.07318031042814255,
#  0.008096965961158276,
#  0.04261280596256256,
#  -0.008675141260027885,
#  -0.001714470679871738,
#  0.026059115305542946,
#  -0.06799541413784027,
#  0.012235724367201328,
#  -0.06176511198282242,
#  0.051078785210847855,
#  0.024933507665991783,
#  -0.043793320655822754,
#  -0.012379665859043598,
#  0.02717060036957264,
#  -0.12399265915155411,
#  0.008453522808849812,
#  -0.02549423649907112,
#  -0.05409914627671242,
#  -0.03286280855536461,
#  0.015627257525920868,
#  -0.022666655480861664,
#  0.09171830117702484,
#  0.051049187779426575,
#  0.052022285759449005,
#  -0.06003211438655853,
#  -0.032160840928554535,
#  0.07382208108901978,
#  -0.019837431609630585,
#  0.05437322333455086,
#  -0.021700432524085045,
#  0.09732038527727127,
#  -0.022395184263586998,
#  0.005283904727548361,
#  -0.009296503849327564,
# ...

# %%
#vector = embedding.embed_documents(doc)

# %%
#vector

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores import Chroma
#from langchain_core.schema import Document
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv
import os

# %%
db = FAISS.from_texts(text,result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 db = FAISS.from_texts(text,result)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)
#    1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)
#    1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)
#    1050         **kwargs,
#    1051     )
#
# ...
