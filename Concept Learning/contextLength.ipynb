# %% [markdown]
# # Context Length
#
# #### it is the no of tokens llm remembers. it depend on the models like: gpt-40 has 1L, gpt-3.5-turbo has 32k
#
# #### if context length is not defined then it will take infinite memory in a loop.

# %% [markdown]
# ### Types :
# ####     1. Limiting number of turns - last N-Messages
# ####     2. Limit by token count - count token limit if excede frop older messages
# ####     3. Summarize message history - like summarize the 50k tokens into 5k tokens
