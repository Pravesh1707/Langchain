# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-3.5-turbo')

# %%
parser = JsonOutputParser()

# %%
prompt = PromptTemplate(template='Provide me with the name, age, city of a fictional person always new and {specific_format}',
                        input_variables=[],partial_variables={'specific_format':parser.get_format_instructions()})

# %%
final_prompt = prompt.format()

# %%
response = model.invoke(final_prompt)

# %%
print(response.content)
# Out:
# {
#     "name": "Emma Parker",
#     "age": 28,
#     "city": "New York City"
# }

# %%
chain = prompt | model | parser

# %%
result = chain.invoke({})

# %%
result
# Out:
# {'name': 'Samantha Grey', 'age': 27, 'city': 'New York'}
