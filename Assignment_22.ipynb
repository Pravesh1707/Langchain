# %%
from langchain_community.document_loaders import TextLoader,PyMuPDFLoader
from langchain_text_splitters import CharacterTextSplitter,RecursiveCharacterTextSplitter

# %%
loader = PyMuPDFLoader('./Data/Sample-filled-in-MR.pdf')
docs = loader.load()
splitter = RecursiveCharacterTextSplitter(chunk_size=300)
chunks = splitter.split_documents(docs)

# %%
print(chunks[0].page_content)
# Out:
# - 1 -
#
# SAMPLE
# (All names and details provided in this sample are fictitious.
# Some fields have been deliberately left blank.)
#
#
# MEDICAL REPORT
#
# SECTION 1: PATIENT’S PARTICULARS
#
# Full name of patient: Mr Tan Ah Kow
#
# NRIC/FIN/Passport no. of patient: S1111111X

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embedding = HuggingFaceEmbeddings(model='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
doc_vector = embedding.embed_documents(chunks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 doc_vector = embedding.embed_documents(chunks)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_huggingface/embeddings/huggingface.py:155, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     145 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     146     """Compute doc embeddings using a HuggingFace transformer model.
#     147
#     148     Args:
#    (...)
#     153
#     154     """
# --> 155     return self._embed(texts, self.encode_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_huggingface/embeddings/huggingface.py:124, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     110 """Embed a text using the HuggingFace transformer model.
#     111
#     112 Args:
#    (...)
#     120
#     121 """
#     122 import sentence_transformers  # type: ignore[import]
# --> 124 texts = [x.replace("\n", " ") for x in texts]
#     125 if self.multi_process:
#     126     pool = self._client.start_multi_process_pool()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_huggingface/embeddings/huggingface.py:124, in <listcomp>(.0)
#     110 """Embed a text using the HuggingFace transformer model.
#     111
#     112 Args:
#    (...)
#     120
#     121 """
#     122 import sentence_transformers  # type: ignore[import]
# --> 124 texts = [x.replace("\n", " ") for x in texts]
#     125 if self.multi_process:
#     126     pool = self._client.start_multi_process_pool()
#
# File ~/Library/Python/3.10/lib/python/site-packages/pydantic/main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Document' object has no attribute 'replace'
